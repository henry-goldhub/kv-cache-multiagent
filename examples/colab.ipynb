# %% [markdown]
# # KVBridge T4 run
# Select a T4 GPU runtime, set `REPO_URL`, and run the cells in order. The notebook only invokes versioned project scripts.

# %%
REPO_URL = "https://github.com/YOUR_ACCOUNT/YOUR_REPOSITORY.git"
# !git clone {REPO_URL} /content/kvbridge
# %cd /content/kvbridge
# !pip install -q -r requirements-colab.lock
# !pip install -q -e .

# %%
# !python examples/calibrate.py

# %%
# !python examples/quickstart.py --num-examples 5 --split train --output-dir results/smoke
# !python examples/quickstart.py --num-examples 200 --split test --output-dir results/final

# %%
# !zip -qr /content/kvbridge-results.zip results artifacts
from google.colab import files
files.download('/content/kvbridge-results.zip')
